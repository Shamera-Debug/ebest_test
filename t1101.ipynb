# %%
import requests
import json
import pprint 
import datetime
import json
import pytz
import pandas as pd
import numpy as np
import requests
import os

import oauth2 as oauth
from datetime import datetime, timedelta
import pytz
import time

# %% [markdown]
# ### API 키 등록하기
# * 개인 api를 발급받으세요.

# %%
# {"appkey":"PSNeOvV92SiRB7a1bbXLYBJt8nuQNicHhLNQ", "appsecret":"Qxud73tJ6NDVGoSXNQckFzJbv7oPI08Q"}

# %%
APP_KEY = "PSNeOvV92SiRB7a1bbXLYBJt8nuQNicHhLNQ"
APP_SECRET = "Qxud73tJ6NDVGoSXNQckFzJbv7oPI08Q"

# %% [markdown]
# ### 접근 토큰 발급받기
# * 하루에 한번씩 받아야합니다.

# %%
def access_token(APP_KEY,APP_SECRET):
    header = {"content-type":"application/x-www-form-urlencoded"}
    param = {"grant_type":"client_credentials",
            "appkey":APP_KEY,
            "appsecretkey":APP_SECRET,
            "scope":"oob"
            }
    PATH = "oauth2/token"
    BASE_URL = "https://openapi.ebestsec.co.kr:8080"
    URL = f"{BASE_URL}/{PATH}"

    request = requests.post(URL, verify=False, headers=header, params=param ,timeout=3)

    if __name__ == "__main__":
        print("URL          : ", URL, "\n")               
        print("OAuth        : ")
        pprint.pprint(request.json()) 
    
    ACCESS_TOKEN = request.json()["access_token"] 

    return ACCESS_TOKEN

# %%
acc_token=access_token(APP_KEY,APP_SECRET)  #토큰 발급 실행
# Out:
# URL          :  https://openapi.ebestsec.co.kr:8080/oauth2/token
#
# OAuth        :
# {'access_token': 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9..B8X7oPaoc6BcpaKfhojvLY5tYUXT85pfXOODDATcKuPyfss9AHa6NuILHkYsuaRjIaIuCKWYe9NXoaR2CyexAQ',
#  'expires_in': 75600,
#  'scope': 'oob',
#  'token_type': 'Bearer'}
# c:\Users\rlagu\.conda\envs\ml-dev\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'openapi.ebestsec.co.kr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
class t1101:
    def t1101(shcode = None, todt = "", period = 365) :
        """
        eBest Open API에서 t1716 TR을 호출하기 위한 URL, 헤더 및 바디 정보를 반환하는 함수입니다.

        Parameters:
            shcode (str, optional)  : 종목코드를 지정하는 매개변수입니다.
            todt (str, optional)    : 조회를 종료할 날짜를 지정하는 매개변수입니다. 기본값은 오늘 날짜로 설정됩니다.
            period (int, optional)  : 조회 기간을 지정하는 매개변수입니다. 기본값은 365일(1년)입니다.

        Returns:
            tuple                   : url, 헤더, 바디 정보, 함수 이름, 반환 데이터 태그, 종목코드를 포함하는 튜플을 반환합니다.
        """

        _url_base   = "https://openapi.ebestsec.co.kr:8080"
        _path       = "stock/market-data"
        _url        = f"{_url_base}/{_path}"

        _header     = {
            "content-type"  : "application/json; charset=UTF-8",
            "authorization" : acc_token,
            "tr_cd"         : "t1101",
            "tr_cont"       : "N",
            "tr_cont_key"   : "",
        }

        _body           ={
            "t1101InBlock" : {
                "shcode" : shcode,  # 종목 코드
            }
        }

        _out_block_tag = "OutBlock"

        return _url, _header, _body, t1101.t1101.__name__, _out_block_tag, shcode

# %%
# if __name__ == "__main__":

#     url, header, body, tr_name, out_block_tag, shcode_ = t1101.t1101()
    
#     print("URL              :")
#     pprint.pprint(url)
#     print("\nheader           :")
#     pprint.pprint(header)
#     print("\nbody             :")
#     pprint.pprint(body)
#     print("\ntr name          :")
#     pprint.pprint(tr_name)
#     print("\nOutBlockTag      :")
#     pprint.pprint(out_block_tag)
#     print("\nshcode           :")
#     pprint.pprint(shcode_)

# %%
def request_tr(url, header, body, tr_name, out_block_tag, shcode,ACCESS_TOKEN):
    """
    eBest Open API에서 TR을 호출하여 데이터를 조회하는 함수입니다.

    Parameters:
        url (str)           : API 호출을 위한 URL입니다.
        header (dict)       : API 호출에 필요한 헤더 정보가 담긴 딕셔너리입니다.
        body (dict)         : API 호출에 필요한 바디 정보가 담긴 딕셔너리입니다.
        tr_name (str)       : 함수 이름입니다.
        out_block_tag (str) : 반환 데이터의 태그입니다.
        shcode (str)        : 종목코드를 지정하는 매개변수입니다.
        ACCESS_TOKEN (str)  : access_token(APP_KEY,APP_SECRET)메소드로 반한된 접근 토큰입니다.
    Returns:
        pandas.DataFrame    : 조회된 데이터가 담긴 DataFrame 객체를 반환합니다.
        str                 : 함수 이름을 반환합니다.
        str                 : 종목코드를 반환합니다.
    """

    header["authorization"] = f"Bearer {ACCESS_TOKEN}"
    _res = requests.post(url, headers=header, data=json.dumps(body), timeout=3.2)   #지정된 시간내에 응답이 오지 않으면 예외가 발생하므로 try/except 구문설정하기
    _json_data = _res.json()
    print(_json_data)                                                          # Ok
    print(f"{tr_name}{out_block_tag}1")                                        # Ok
    _data_frame = pd.json_normalize(_json_data[f"{tr_name}{out_block_tag}"])    #json양식을 데이터 프레임으로 바꾸기

    return _data_frame, tr_name, shcode

# %%
def save_csv(data_frame, tr_name, shcode=""):
    """
    조회된 데이터를 CSV 파일로 저장하는 함수입니다.

    Parameters:
        data_frame (pandas.DataFrame) : 조회된 데이터가 담긴 DataFrame 객체입니다.
        tr_name (str)                 : 저장할 파일의 이름을 지정하는 매개변수입니다.
        shcode (str, optional)        : 종목코드를 지정하는 매개변수입니다. 기본값은 ""(빈 문자열)입니다.

    Returns:
        None
    """

    _seoul_timezone = pytz.timezone('Asia/Seoul')
    # _time_stamp = datetime.now(_seoul_timezone).strftime("%Y%m%d_%H%M%S")
    _time_stamp = datetime.now(_seoul_timezone).strftime("%Y%m%d")
    
    
    if len(shcode) > 0:
        _path = f'C:\ebest_ml_dev\ebest\csv\{tr_name.upper()}_{shcode}_{_time_stamp}.csv'
    else:
        _path = f'C:\ebest_ml_dev\ebest\csv\{tr_name.upper()}_{_time_stamp}.csv'
            
            
    if os.path.exists(_path):
        # If the file already exists, append the data
        data_frame.to_csv(_path, mode='a', header=False, index=False)
        print("파일에 데이터를 추가했습니다. :", _path)
    else:
        # If the file does not exist, create a new file
        data_frame.to_csv(_path, index=False)
        print("새로운 파일을 생성하고 데이터를 저장했습니다. :", _path)

# %%
import schedule
from datetime import datetime, timezone, timedelta

def mainFunc(): 
    if __name__ == "__main__":
        code = "005930"    
        while True:
            results, tr_name, shcode = request_tr(*t1101.t1101(shcode=code, period=365), ACCESS_TOKEN=acc_token)
            print(results)
            save_csv(results, tr_name, shcode)
            
            # Sleep for 3.2 seconds before the next iteration
            time.sleep(2.5)

# %%
schedule.every().monday.at("10:45").do(mainFunc)
while True:   
    schedule.run_pending()
# Out:
# {'t1101OutBlock': {'hname': '삼성전자', 'price': 
 'preoffercha3': 0, 'prebidcha3': 0, 'offerho4': 77500, 'bidho4': 76800, 'offerrem4': 125698, 'bidrem4': 187135, 'preoffercha4': 0, 'prebidcha4': 0, 'offerho5': 77600, 'bidho5': 76700, 'offerrem5': 98287, 'bidrem5': 174557, 'preoffercha5': 0, 'prebidcha5': 0, 'offerho6': 77700, 'bidho6': 76600, 'offerrem6': 135710, 'bidrem6': 180593, 'preoffercha6': 0, 'prebidcha6': 0, 'offerho7': 77800, 'bidho7': 76500, 'offerrem7': 138791, 'bidrem7': 192683, 'preoffercha7': 0, 'prebidcha7': 0, 'offerho8': 77900, 'bidho8': 76400, 'offerrem8': 129122, 'bidrem8': 135070, 'preoffercha8': 0, 'prebidcha8': 0, 'offerho9': 78000, 'bidho9': 76300, 'offerrem9': 119985, 'bidrem9': 170511, 'preoffercha9': 0, 'prebidcha9': 0, 'offerho10': 78100, 'bidho10': 76200, 'offerrem10': 27589, 'bidrem10': 191925, 'preoffercha10': 0, 'prebidcha10': 0, 'offer': 1125546, 'bid': 1820743, 'preoffercha': 0, 'prebidcha': 0, 'hotime': '10415760', 'yeprice': 0, 'yevolume': 0, 'yesign': '3', 'yechange': 0, 'yediff': '0.00', 'tmoffer': 0, 'tmbid': 0, 'ho_status': '1', 'shcode': '005930', 'uplmtprice': 99500, 'dnlmtprice': 53700, 'open': 77000, 'high': 77500, 'low': 76800}, 'rsp_cd': '00000', 'rsp_msg': '정상적으로 조회가 완료되었습니다.'}
# t1101OutBlock1
#   hname  price sign  change  diff   volume  jnilclose  offerho1  bidho1  \
# 0  삼성전자  77200    2     600  0.78  4306217      76600     77200   77100
#
#    offerrem1  ...  yediff  tmoffer  tmbid  ho_status  shcode  uplmtprice  \
# 0     153658  ...    0.00        0      0          1  005930       99500
#
#    dnlmtprice   open   high    low
# 0       53700  77000  77500  76800
#
# [1 rows x 86 columns]
# 파일에 데이터를 추가했습니다. : C:\ebest_ml_dev\ebest\csv\T1101_005930_20240108.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[92], line 3
#       1 schedule.every().monday.at("10:45").do(mainFunc)
#       2 while True:
# ----> 3     schedule.run_pending()
#
# File c:\Users\rlagu\.conda\envs\ml-dev\lib\site-packages\schedule\__init__.py:822, in run_pending()
#     818 def run_pending() -> None:
#     819     """Calls :meth:`run_pending <Scheduler.run_pending>` on the
#     820     :data:`default scheduler instance <default_scheduler>`.
#     821     """
# --> 822     default_scheduler.run_pending()
#
# File c:\Users\rlagu\.conda\envs\ml-dev\lib\site-packages\schedule\__init__.py:100, in Scheduler.run_pending(self)
#      98 runnable_jobs = (job for job in self.jobs if job.should_run)
#      99 for job in sorted(runnable_jobs):
# --> 100     self._run_job(job)
#
# File c:\Users\rlagu\.conda\envs\ml-dev\lib\site-packages\schedule\__init__.py:172, in Scheduler._run_job(self, job)
#     171 def _run_job(self, job: "Job") -> None:
# --> 172     ret = job.run()
#     173     if isinstance(ret, CancelJob) or ret is CancelJob:
#     174         self.cancel_job(job)
#
# File c:\Users\rlagu\.conda\envs\ml-dev\lib\site-packages\schedule\__init__.py:693, in Job.run(self)
#     690     return CancelJob
#     692 logger.debug("Running job %s", self)
# --> 693 ret = self.job_func()
#     694 self.last_run = datetime.datetime.now()
#     695 self._schedule_next_run()
#
# Cell In[22], line 10, in mainFunc()
#       7 save_csv(results, tr_name, shcode)
#       9 # Sleep for 3.2 seconds before the next iteration
# ---> 10 time.sleep(2.5)
#
# KeyboardInterrupt:

# %%
# if __name__ == "__main__":
#     code = "005930"    
#     while True:
#         results, tr_name, shcode = request_tr(*t1101.t1101(shcode=code, period=365), ACCESS_TOKEN=acc_token)
#         print(results)
#         save_csv(results, tr_name, shcode)
        
#         # Sleep for 3.2 seconds before the next iteration
#         time.sleep(2.5)
# Out:
# {'t1101OutBlock': {'hname': '삼성전자', 'price': 77400, 'sign': '2', 'change': 800, 'diff': '1.04', 'volume': 3808759, 'jnilclose': 76600, 'offerho1': 77500, 'bidho1': 77400, 'offerrem1': 135846, 'bidrem1': 137051, 'preoffercha1': 0, 'prebidcha1': -10, 'offerho2': 77600, 'bidho2': 77300, 'offerrem2': 153270, 'bidrem2': 125507, 'preoffercha2': 0, 'prebidcha2': 0, 'offerho3': 77700, 'bidho3': 77200, 'offerrem3': 146878, 'bidrem3': 163566, 'preoffercha3': 0, 'prebidcha3': 0, 'offerho4': 77800, 'bidho4': 77100, 'offerrem4': 156144, 'bidrem4': 155715, 'preoffercha4': 0, 'prebidcha4': 0, 'offerho5': 77900, 'bidho5': 77000, 'offerrem5': 125639, 'bidrem5': 362146, 'preoffercha5': 0, 'prebidcha5': 0, 'offerho6': 78000, 'bidho6': 76900, 'offerrem6': 108172, 'bidrem6': 229460, 'preoffercha6': 0, 'prebidcha6': 0, 'offerho7': 78100, 'bidho7': 76800, 'offerrem7': 26040, 'bidrem7': 187562, 'preoffercha7': 0, 'prebidcha7': 0, 'offerho8': 78200, 'bidho8': 76700, 'offerrem8': 32402, 'bidrem8': 174267, 'preoffercha8': 0, 'prebidcha8': 0, 'offerho9': 78300, 'bidho9': 76600, 'offerrem9': 21756, 'bidrem9': 192735, 'preoffercha9': 0, 'prebidcha9': 0, 'offerho10': 78400, 'bidho10': 76500, 'offerrem10': 14347, 'bidrem10': 192615, 'preoffercha10': 0, 'prebidcha10': 0, 'offer': 920494, 'bid': 1920624, 'preoffercha': 0, 'prebidcha': 0, 'hotime': '10194206', 'yeprice': 0, 'yevolume': 0, 'yesign': '3', 'yechange': 0, 'yediff': '0.00', 'tmoffer': 0, 'tmbid': 0, 'ho_status': '1', 'shcode': '005930', 'uplmtprice': 99500, 'dnlmtprice': 53700, 'open': 77000, 'high': 77500, 'low': 76800}, 'rsp_cd': '00000', 'rsp_msg': '정상적으로 조회가 완료되었습니다.'}
# t1101OutBlock1
#   hname  price sign  change  diff   volume  jnilclose  offerho1  bidho1  \
# 0  삼성전자  77400    2     800  1.04  3808759      76600     77500   77400
#
#    offerrem1  ...  yediff  tmoffer  tmbid  ho_status  shcode  uplmtprice  \
# 0     135846  ...    0.00        0      0          1  005930       99500
#
#    dnlmtprice   open   high    low
# 0       53700  77000  77500  76800
#
# [1 rows x 86 columns]
# 파일에 데이터를 추가했습니다. : C:\ebest_ml_dev\ebest\csv\T1101_005930_20240108.csv
# {'t1101OutBlock': {'hname': '삼성전자', 'price': 77500, 'sign': '2', 'change': 900, 'diff': '1.17', 'volume': 3809372, 'jnilclose': 76600, 'offerho1': 77500, 'bidho1': 77400, 'offerrem1': 136137, 'bidrem1': 137087, 'preoffercha1': 0, 'prebidcha1': 0, 'offerho2': 77600, 'bidho2': 77300, 'offerrem2': 153270, 'bidrem2': 125705, 'preoffercha2': 0, 'prebidcha2': 0, 'offerho3': 77700, 'bidho3': 77200, 'offerrem3': 146882, 'bidrem3': 163625, 'preoffercha3': -1, 'prebidcha3': 0, 'offerho4': 77800, 'bidho4': 77100, 'offerrem4': 156144, 'bidrem4': 155715, 'preoffercha4': 0, 'prebidcha4': 0, 'offerho5': 77900, 'bidho5': 77000, 'offerrem5': 125636, 'bidrem5': 361991, 'preoffercha5': 1, 'prebidcha5': 0, 'offerho6': 78000, 'bidho6': 76900, 'offerrem6':
 'preoffercha2': 0, 'prebidcha2': 0, 'offerho3': 77700, 'bidho3': 77200, 'offerrem3': 149944, 'bidrem3': 163921, 'preoffercha3': 0, 'prebidcha3': 0, 'offerho4': 77800, 'bidho4': 77100, 'offerrem4': 155831, 'bidrem4': 151262, 'preoffercha4': 0, 'prebidcha4': 0, 'offerho5': 77900, 'bidho5': 77000, 'offerrem5': 145837, 'bidrem5': 362047, 'preoffercha5': 0, 'prebidcha5': 0, 'offerho6': 78000, 'bidho6': 76900, 'offerrem6': 128205, 'bidrem6': 229420, 'preoffercha6': 0, 'prebidcha6': 0, 'offerho7': 78100, 'bidho7': 76800, 'offerrem7': 45977, 'bidrem7': 187764, 'preoffercha7': 0, 'prebidcha7': 0, 'offerho8': 78200, 'bidho8': 76700, 'offerrem8': 32504, 'bidrem8': 174342, 'preoffercha8': 0, 'prebidcha8': 0, 'offerho9': 78300, 'bidho9': 76600, 'offerrem9': 21761, 'bidrem9': 192395, 'preoffercha9': 0, 'prebidcha9': 0, 'offerho10': 78400, 'bidho10': 76500, 'offerrem10': 14491, 'bidrem10': 192503, 'preoffercha10': 0, 'prebidcha10': 0, 'offer': 984801, 'bid': 1915259, 'preoffercha': 1, 'prebidcha': 1, 'hotime': '10202879', 'yeprice': 0, 'yevolume': 0, 'yesign': '3', 'yechange': 0, 'yediff': '0.00', 'tmoffer': 0, 'tmbid': 0, 'ho_status': '1', 'shcode': '005930', 'uplmtprice': 99500, 'dnlmtprice': 53700, 'open': 77000, 'high': 77500, 'low': 76800}, 'rsp_cd': '00000', 'rsp_msg': '정상적으로 조회가 완료되었습니다.'}
# t1101OutBlock1
#   hname  price sign  change  diff   volume  jnilclose  offerho1  bidho1  \
# 0  삼성전자  77400    2     800  1.04  3817186      76600     77500   77400
#
#    offerrem1  ...  yediff  tmoffer  tmbid  ho_status  shcode  uplmtprice  \
# 0     134820  ...    0.00        0      0          1  005930       99500
#
#    dnlmtprice   open   high    low
# 0       53700  77000  77500  76800
#
# [1 rows x 86 columns]
# 파일에 데이터를 추가했습니다. : C:\ebest_ml_dev\ebest\csv\T1101_005930_20240108.csv
# {'t1101OutBlock': {'hname': '삼성전자', 'price': 77400, 'sign': '2', 'change': 800, 'diff': '1.04', 'volume': 3817445, 'jnilclose': 76600, 'offerho1': 77500, 'bidho1': 77400, 'offerrem1': 138655, 'bidrem1': 128567, 'preoffercha1': 0, 'prebidcha1': -26, 'offerho2': 77600, 'bidho2': 77300, 'offerrem2': 151533, 'bidrem2': 132726, 'preoffercha2': 0, 'prebidcha2': 0, 'offerho3': 77700, 'bidho3': 77200, 'offerrem3': 149841, 'bidrem3': 165328, 'preoffercha3': 0, 'prebidcha3': 0, 'offerho4': 77800, 'bidho4': 77100, 'offerrem4': 155832, 'bidrem4': 151262, 'preoffercha4': 0, 'prebidcha4': 0, 'offerho5': 77900, 'bidho5': 77000, 'offerrem5': 145858, 'bidrem5': 362048, 'preoffercha5': 0, 'prebidcha5': 0, 'offerho6': 78000, 'bidho6': 76900, 'offerrem6': 128240, 'bidrem6': 229424, 'preoffercha6': 0, 'prebidcha6': 0, 'offerho7': 78100, 'bidho7': 76800, 'offerrem7': 45977, 'bidrem7': 187764, 'preoffercha7': 0, 'prebidcha7': 0, 'offerho8': 78200, 'bidho8': 76700, 'offerrem8': 32504, 'bidrem8': 174342, 'preoffercha8': 0, 'prebidcha8': 0, 'offerho9': 78300, 'bidho9': 76600, 'offerrem9': 21761, 'bidrem9': 192400, 'preoffercha9': 0, 'prebidcha9': 0, 'offerho10': 78400, 'bidho10': 76500, 'offerrem10': 14591, 'bidrem10': 192503, 'preoffercha10': 0, 'prebidcha10': 0, 'offer': 984792, 'bid': 1916364, 'preoffercha': 0, 'prebidcha': 0, 'hotime': '10203203', 'yeprice': 0, 'yevolume': 0, 'yesign': '3', 'yechange': 0, 'yediff': '0.00', 'tmoffer': 0, 'tmbid': 0, 'ho_status': '1', 'shcode': '005930', 'uplmtprice': 99500, 'dnlmtprice': 53700, 'open': 77000, 'high': 77500, 'low': 76800}, 'rsp_cd': '00000', 'rsp_msg': '정상적으로 조회가 완료되었습니다.'}
# t1101OutBlock1
#   hname  price sign  change  diff   volume  jnilclose  offerho1  bidho1  \
# 0  삼성전자  77400    2     800  1.04  3817445      76600     77500   77400
#
#    offerrem1  ...  yediff  tmoffer  tmbid  ho_status  shcode  uplmtprice  \
# 0     138655  ...    0.00        0      0          1  005930       99500
#
#    dnlmtprice   open   high    low
# 0       53700  77000  77500  76800
#
# [1 rows x 86 columns]
# 파일에 데이터를 추가했습니다. : C:\ebest_ml_dev\ebest\csv\T1101_005930_20240108.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 9
#       6 save_csv(results, tr_name, shcode)
#       8 # Sleep for 3.2 seconds before the next iteration
# ----> 9 time.sleep(2.5)
#
# KeyboardInterrupt:
