# %%
import requests
import json
import pprint 
import datetime
import json
import pytz
import pandas as pd
import numpy as np
import requests

import oauth2 as oauth
from datetime import datetime, timedelta
import pytz
import time

# %%
import datetime
import json
import pytz
import pandas as pd
import numpy as np
import requests

import oauth2 as oauth
from datetime import datetime, timedelta
import pytz
import time

# %%
import os

# %% [markdown]
# ### API 키 등록하기
# * 개인 api를 발급받으세요.

# %%
# {"appkey":"PSNeOvV92SiRB7a1bbXLYBJt8nuQNicHhLNQ", "appsecret":"Qxud73tJ6NDVGoSXNQckFzJbv7oPI08Q"}
# Out:
# {'appkey': 'PSNeOvV92SiRB7a1bbXLYBJt8nuQNicHhLNQ',
#  'appsecret': 'Qxud73tJ6NDVGoSXNQckFzJbv7oPI08Q'}

# %%
APP_KEY = "PSNeOvV92SiRB7a1bbXLYBJt8nuQNicHhLNQ"
APP_SECRET = "Qxud73tJ6NDVGoSXNQckFzJbv7oPI08Q"

# %% [markdown]
# ### 접근 토큰 발급받기
# * 하루에 한번씩 받아야합니다.

# %%
def access_token(APP_KEY,APP_SECRET):
    header = {"content-type":"application/x-www-form-urlencoded"}
    param = {"grant_type":"client_credentials",
            "appkey":APP_KEY,
            "appsecretkey":APP_SECRET,
            "scope":"oob"
            }
    PATH = "oauth2/token"
    BASE_URL = "https://openapi.ebestsec.co.kr:8080"
    URL = f"{BASE_URL}/{PATH}"

    request = requests.post(URL, verify=False, headers=header, params=param ,timeout=3)

    if __name__ == "__main__":
        print("URL          : ", URL, "\n")               
        print("OAuth        : ")
        pprint.pprint(request.json()) 
    
    ACCESS_TOKEN = request.json()["access_token"] 

    return ACCESS_TOKEN

# %%
acc_token=access_token(APP_KEY,APP_SECRET)  #토큰 발급 실행
acc_token
# Out:
# URL          :  https://openapi.ebestsec.co.kr:8080/oauth2/token
#
# OAuth        :
# {'access_token': 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9..RrIyPpJgiBKHNXa0PzUeUfHHmvQV5AIXOFoNfQptqvuz-5uZ6EGj0ePhckxzQhTWfqXA65uER1I9SkGXkVo5XQ',
#  'expires_in': 46658,
#  'scope': 'oob',
#  'token_type': 'Bearer'}
# c:\Users\rlagu\.conda\envs\ml-dev\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'openapi.ebestsec.co.kr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9..RrIyPpJgiBKHNXa0PzUeUfHHmvQV5AIXOFoNfQptqvuz-5uZ6EGj0ePhckxzQhTWfqXA65uER1I9SkGXkVo5XQ'

# %%
class t8412:
    def t8412(shcode = None, todt = "", period = 364) :
        """
        eBest Open API에서 t1716 TR을 호출하기 위한 URL, 헤더 및 바디 정보를 반환하는 함수입니다.

        Parameters:
            shcode (str, optional)  : 종목코드를 지정하는 매개변수입니다.
            todt (str, optional)    : 조회를 종료할 날짜를 지정하는 매개변수입니다. 기본값은 오늘 날짜로 설정됩니다.
            period (int, optional)  : 조회 기간을 지정하는 매개변수입니다. 기본값은 365일(1년)입니다.

        Returns:
            tuple                   : url, 헤더, 바디 정보, 함수 이름, 반환 데이터 태그, 종목코드를 포함하는 튜플을 반환합니다.
        """

        _url_base   = "https://openapi.ebestsec.co.kr:8080"
        _path       = "stock/chart"
        _url        = f"{_url_base}/{_path}"

        _header     = {
            "content-type"  : "application/json; charset=UTF-8",
            "authorization" : acc_token,                             # fill in RunTR()
            "tr_cd"         : "t8412",
            "tr_cont"       : "N",
            "tr_cont_key"   : "",
            "mac_address"   : ""
        }

        # 시작일자와 종료일자를 YYYYMMDD 형식으로 생성하기
        #오늘날짜 구하기(종료일)
        _seoul_timezone = pytz.timezone('Asia/Seoul')
        _seoul_dt       = datetime.now(_seoul_timezone)
        _todt           = _seoul_dt.strftime('%Y%m%d') if todt == "" else todt
        #1년전 구하기(시작일)
        _todt_datetime = datetime.strptime(_todt, '%Y%m%d').astimezone(_seoul_timezone)
        _fromdt = (_todt_datetime - timedelta(period)).strftime("%Y%m%d")
          
        print(_todt)
        print(_fromdt)
        _body           ={
            "t8412InBlock" : {
                "shcode" : shcode ,             #종목코드 String
                "ncnt" : 1,                     #단위(n분) Number
                "qrycnt" : 500,                  #요청건수(최대-압축:2000 비압축 :500) Number
                "nday" : "5",                   #조회영업일수(0:미사용 1>=사용) String
                "sdate" : "20230103",              #시작일자   String
                "stime" : "090000",             #시작시간(현재미사용)   String
                "edate" : "20231013",                #종료일자   String
                "etime" : "153000",             #종료시간(현재미사용)   String
                "cts_date" : "1",               #연속일자   String
                "cts_time" : "1",               #연속시간   String
                "comp_yn" : "N"                 #압축여부(Y:압축N:비압축)   String
            }
        }

        _out_block_tag = "OutBlock"

        return _url, _header, _body, t8412.t8412.__name__, _out_block_tag, shcode

# %%
if __name__ == "__main__":

    url, header, body, tr_name, out_block_tag, shcode_ = t8412.t8412()
    
    print("URL              :")
    pprint.pprint(url)
    print("\nheader           :")
    pprint.pprint(header)
    print("\nbody             :")
    pprint.pprint(body)
    print("\ntr name          :")
    pprint.pprint(tr_name)
    print("\nOutBlockTag      :")
    pprint.pprint(out_block_tag)
    print("\nshcode           :")
    pprint.pprint(shcode_)
# Out:
# 20240102
# 20230103
# URL              :
# 'https://openapi.ebestsec.co.kr:8080/stock/chart'
#
# header           :
# {'authorization': 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9..RrIyPpJgiBKHNXa0PzUeUfHHmvQV5AIXOFoNfQptqvuz-5uZ6EGj0ePhckxzQhTWfqXA65uER1I9SkGXkVo5XQ',
#  'content-type': 'application/json; charset=UTF-8',
#  'mac_address': '',
#  'tr_cd': 't8412',
#  'tr_cont': 'N',
#  'tr_cont_key': ''}
#
# body             :
# {'t8412InBlock': {'comp_yn': 'N',
#                   'cts_date': '1',
#                   'cts_time': '1',
#                   'edate': '20231013',
#                   'etime': '153000',
#                   'ncnt': 1,
#                   'nday': '5',
#                   'qrycnt': 500,
#                   'sdate': '20230103',
#                   'shcode': None,
#                   'stime': '090000'}}
#
# tr name          :
# 't8412'
#
# OutBlockTag      :
# 'OutBlock'
#
# shcode           :
# None

# %%
def request_tr(url, header, body, tr_name, out_block_tag, shcode,ACCESS_TOKEN):
    """
    eBest Open API에서 TR을 호출하여 데이터를 조회하는 함수입니다.

    Parameters:
        url (str)           : API 호출을 위한 URL입니다.
        header (dict)       : API 호출에 필요한 헤더 정보가 담긴 딕셔너리입니다.
        body (dict)         : API 호출에 필요한 바디 정보가 담긴 딕셔너리입니다.
        tr_name (str)       : 함수 이름입니다.
        out_block_tag (str) : 반환 데이터의 태그입니다.
        shcode (str)        : 종목코드를 지정하는 매개변수입니다.
        ACCESS_TOKEN (str)  : access_token(APP_KEY,APP_SECRET)메소드로 반한된 접근 토큰입니다.
    Returns:
        pandas.DataFrame    : 조회된 데이터가 담긴 DataFrame 객체를 반환합니다.
        str                 : 함수 이름을 반환합니다.
        str                 : 종목코드를 반환합니다.
    """

    header["authorization"] = f"Bearer {ACCESS_TOKEN}"
    _res = requests.post(url, headers=header, data=json.dumps(body), timeout=3.2)   #지정된 시간내에 응답이 오지 않으면 예외가 발생하므로 try/except 구문설정하기
    _json_data = _res.json()
    print(_json_data)                                                          # Ok
    print(f"{tr_name}{out_block_tag}1")                                        # Ok
    _data_frame = pd.json_normalize(_json_data[f"{tr_name}{out_block_tag}1"])    #json양식을 데이터 프레임으로 바꾸기

    return _data_frame, tr_name, shcode

# %%
def save_csv(data_frame, tr_name, shcode=""):
    """
    조회된 데이터를 CSV 파일로 저장하는 함수입니다.

    Parameters:
        data_frame (pandas.DataFrame) : 조회된 데이터가 담긴 DataFrame 객체입니다.
        tr_name (str)                 : 저장할 파일의 이름을 지정하는 매개변수입니다.
        shcode (str, optional)        : 종목코드를 지정하는 매개변수입니다. 기본값은 ""(빈 문자열)입니다.

    Returns:
        None
    """

    _seoul_timezone = pytz.timezone('Asia/Seoul')
    _time_stamp = datetime.now(_seoul_timezone).strftime("%Y%m%d_%H%M%S")
    if len(shcode) > 0:
        _path = f'C:\education\ebest\csv\{tr_name.upper()}_{shcode}_{_time_stamp}.csv'
    else:
        _path = f'C:\education\ebest\csv\{tr_name.upper()}_{_time_stamp}.csv'
    data_frame.to_csv(_path)
    print("파일 저장을 완료하였습니다. :", _path)

# %%
if __name__ == "__main__":
    # df=pd.read_csv('./6.csv')
    # codes=df.iloc[:200,]['종목코드'].to_list()
        code="005940"
    # for code in codes:
        results, tr_name, shcode = request_tr(*t8412.t8412(shcode=code, period=365),ACCESS_TOKEN=acc_token)             # 삼성전자, 1년치 일일 데이터
        print(results)
        
        save_csv(results, tr_name, shcode)
        #time.sleep(3.2)
# Out:
133500', 'open': 10560, 'high': 10570, 'low': 10560, 'close': 10560, 'jdiff_vol': 416, 'value': 4, 'jongchk': 0, 'rate': '0.00', 'sign': '2'}, {'date': '20231012', 'time': '133600', 'open': 10560, 'high': 10570, 'low': 10560, 'close': 10560, 'jdiff_vol': 255, 'value': 3, 'jongchk': 0, 'rate': '0.00', 'sign': '2'}, {'date': '20231012', 'time': '133700', 'open': 10560, 'high': 10570, 'low': 10560, 'close': 10560, 'jdiff_vol': 500, 'value': 5, 'jongchk': 0, 'rate': '0.00', 'sign': '2'}, {'date': '20231012', 'time': '133800', 'open': 10560, 'high': 10570, 'low': 10560, 'close': 10560, 'jdiff_vol': 514, 'value': 5, 'jongchk': 0, 'rate': '0.00', 'sign': '2'}, {'date': '20231012', 'time': '133900', 'open': 10560, 'high': 10570, 'low': 10560, 'close': 10560, 'jdiff_vol': 526, 'value': 6, 'jongchk': 0, 'rate': '0.00', 'sign': '2'}, {'date': '20231012', 'time': '134000', 'open': 10560, 'high': 10570, 'low': 10560, 'close': 10560, 'jdiff_vol': 483, 'value': 5, 'jongchk': 0, 'rate': '0.00', 'sign': '2'}, {'date': '20231012', 'time': '134100', 'open': 10560, 'high': 10570, 'low': 10560, 'close': 10560, 'jdiff_vol': 559, 'value': 6, 'jongchk': 0, 'rate': '0.00', 'sign': '2'}, {'date': '20231012', 'time': '134200', 'open': 10560, 'high': 10570, 'low': 10560, 'close': 10560, 'jdiff_vol': 470, 'value': 5, 'jongchk': 0, 'rate': '0.00', 'sign': '2'}, {'date': '20231012', 'time': '134300', 'open': 10560, 'high': 10570, 'low': 10560, 'close': 10560, 'jdiff_vol': 198, 'value': 2, 'jongchk': 0, 'rate': '0.00', 'sign ...
# t8412OutBlock1
#          date    time   open   high    low  close  jdiff_vol  value  jongchk  \
# 0    20231012  132300  10560  10570  10560  10560       1110     12        0
# 1    20231012  132400  10560  10570  10560  10560        999     11        0
# 2    20231012  132500  10560  10570  10560  10560        547      6        0
# 3    20231012  132600  10560  10580  10560  10580       4414     47        0
# 4    20231012  132700  10570  10580  10570  10570        278      3        0
# ..        ...     ...    ...    ...    ...    ...        ...    ...      ...
# 495  20231013  151700  10530  10540  10530  10530       1744     18        0
# 496  20231013  151800  10530  10550  10530  10550       2018     21        0
# 497  20231013  151900  10540  10550  10540  10550        870      9        0
# 498  20231013  152000  10550  10590  10540  10540       8191     87        0
# 499  20231013  153000  10550  10550  10550  10550      41854    442        0
#
#      rate sign
# 0    0.00    2
# 1    0.00    2
# 2    0.00    2
# 3    0.00    2
# 4    0.00    2
# ..    ...  ...
# 495  0.00    5
# 496  0.00    5
# 497  0.00    5
# 498  0.00    5
# 499  0.00    5
#
# [500 rows x 11 columns]
# 파일 저장을 완료하였습니다. : C:\education\ebest\csv\T8412_005940_20240102_180512.csv
